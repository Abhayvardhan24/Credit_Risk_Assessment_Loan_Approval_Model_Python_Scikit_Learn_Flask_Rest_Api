# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Model_data_xyz.xlsx')

# %%
x = data.iloc[0::,0:18]

# %%
y = data['loan_status']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 , random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier

# %%
model_pipeline = Pipeline([
    ('Scal', StandardScaler()),
    ('GBM', GradientBoostingClassifier(n_estimators=150,
                                     learning_rate=0.05,
                                     max_depth=3,
                                     subsample=0.8,
                                     random_state=42))
])

# %%
GradientBoostingClassifier()
# Out:
# GradientBoostingClassifier()

# %%
model_pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('Scal', StandardScaler()),
#                 ('GBM',
#                  GradientBoostingClassifier(learning_rate=0.05,
#                                             n_estimators=150, random_state=42,
#                                             subsample=0.8))])

# %%
y_predict = model_pipeline.predict(x_test)

# %%
model_pipeline.score(x_train , y_train) # Training
# Out:
# 0.9088340628730601

# %%
model_pipeline.score(x_test , y_test) # Testing Score
# Out:
# 0.9062549737386599

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test , y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87      2423
#            1       0.91      0.95      0.93      3860
#
#     accuracy                           0.91      6283
#    macro avg       0.91      0.89      0.90      6283
# weighted avg       0.91      0.91      0.91      6283

# %%
import pickle

# model = your trained ML model
with open("model_pipeline.pkl", "wb") as file:
    pickle.dump(model, file)

print("Model saved successfully!")
